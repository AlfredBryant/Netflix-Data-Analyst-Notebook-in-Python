# %%
# Importing the dataset
import pandas as pd
data = pd.read_csv(r"C:\Users\lj198\Downloads\Netflix\Netflix Dataset.csv")
 # to import pandas library

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
     #Getting some basic information about the dataset

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
# to show the No. of Rows and Columns

# %%
data.shape
# Out:
# (7789, 11)

# %%
# to show No. of total values(elements) in the dataset

# %%
data.size
# Out:
# 85679

# %%
# to show each Column Name

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
# to show the data-type of each coulumn

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# to show indexes, columns data-types of each column, memory at once

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
Task2. # finding any duplicate records

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
# to remove the duplicate rows permanently

# %%
data.drop_duplicates(inplace = True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.shape
# Out:
# (7787, 11)

# %%
Task #2 Null Value

# %%
isnull()     # to show where Null value is present

# %%
            # to show the count of Null values in each column

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
        # To Show the count of Null values in each column

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
       # to import Seaborn library

# %%
import seaborn as sns

# %%
     # Using heat-map to show null values count

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
Q.1    For 'House of Cards', what is the Show_Id and Who is the Director of this show ?

# %%
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
   # To show all records of a particular string in any coulmn

# %%
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
Q.2   Which year highest number of the TV Shows & Movies were released? Show with Bar Graph.

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data['Release_Date'] = pd.to_datetime(data['Release_Date'], errors='coerce')

# %%
data['Release_Date'].dt.year
# Out:
# 0       2020.0
# 1       2016.0
# 2       2018.0
# 3       2017.0
# 4       2020.0
#          ...
# 7784    2020.0
# 7785    2019.0
# 7786    2020.0
# 7787    2020.0
# 7788    2020.0
# Name: Release_Date, Length: 7787, dtype: float64

# %%
data['Release_Date'].dt.year.value_counts()
# Out:
# Release_Date
# 2019.0    2136
# 2020.0    2008
# 2018.0    1661
# 2017.0    1201
# 2016.0     432
# 2021.0     117
# 2015.0      79
# 2014.0      24
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data['Date_N'] = pd.to_datetime(data['Release_Date'])

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 2019.0    2136
# 2020.0    2008
# 2018.0    1661
# 2017.0    1201
# 2016.0     432
# 2021.0     117
# 2015.0      79
# 2014.0      24
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_N'>

# %%
Q.3  How many Movies & TV Shows are in the dataset? Show with Bar Graph.

# %%
# To group all unique items of a column & show their count

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data.groupby('Category')

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
  # to show the count of all unique values of any column in the form of bar graph

# %%
sns.countplot(data['Category'])
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
Q.4  Show all the Movies that were released in year 2000

# %%
         # Creating New Column

# %%
# data.head()
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data['Year'] = data['Date_N'].dt.year

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
   #Filtering

# %%
data[(data['Category'] == 'Movie') & (data['Year']==2000) ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
data[(data['Category'] == 'Movie') & (data['Year']==2020) ]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
 Q.5  Show only the Titles of all TV Shows that were released in United States only.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[(data['Category']=='TV Show') & (data['Country']=='United States')]
# Out:
#      Show_Id Category                               Title            Director  \
# 26       s27  TV Show                            (Un)Well                 NaN
# 29       s30  TV Show                            #blackAF                 NaN
# 53       s54  TV Show                          100 Humans                 NaN
# 63       s64  TV Show                      13 Reasons Why                 NaN
# 64       s65  TV Show  13 Reasons Why: Beyond the Reasons                 NaN
# ...      ...      ...                                 ...                 ...
# 7714   s7713  TV Show                        Yo-Kai Watch                 NaN
# 7723   s7722  TV Show                                 You  Lee Toland Krieger
# 7732   s7731  TV Show                        You vs. Wild                 NaN
# 7737   s7736  TV Show                      Young & Hungry                 NaN
# 7757   s7756  TV Show                            Z Nation                 NaN
#
# ...

# %%
data[(data['Category']=='TV Show') & (data['Country']=='United States')] ['Title']
# Out:
# 26                                (Un)Well
# 29                                #blackAF
# 53                              100 Humans
# 63                          13 Reasons Why
# 64      13 Reasons Why: Beyond the Reasons
#                        ...
# 7714                          Yo-Kai Watch
# 7723                                   You
# 7732                          You vs. Wild
# 7737                        Young & Hungry
# 7757                              Z Nation
# Name: Title, Length: 705, dtype: object

# %%
Q.6 Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix?

# %%
# data['Director'].value_counts().head(5)
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data['Director'].value_counts().head(5)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Name: count, dtype: int64

# %%
Q.7 Can you show all the Records, where "Category is Movie & Type is Comedies" or "Country is United States"

# %%
data[(data['Category']=='Movie') & (data['Type']=='Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
data[(data['Category']== 'Movie') & (data['Type']=='Comedies') | (data['Country']=='United States')]
# Out:
#      Show_Id Category                       Title         Director  \
# 3         s4    Movie                           9      Shane Acker
# 4         s5    Movie                          21   Robert Luketic
# 7         s8    Movie                         187   Kevin Reynolds
# 10       s11    Movie                        1922     Zak Hilditch
# 14       s15    Movie                        3022       John Suits
# ...      ...      ...                         ...              ...
# 7760   s7759    Movie  Zack and Miri Make a Porno      Kevin Smith
# 7773   s7772    Movie                        Zion       Floyd Russ
# 7776   s7775    Movie                      Zodiac    David Fincher
# 7780   s7779    Movie                  Zombieland  Ruben Fleischer
# 7783   s7782    Movie                        Zoom     Peter Hewitt
#
#                                                    Cast        Country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %%
Q8. How many movies/shows, Denzel Washington was cast?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
[data['Cast']== 'Denzel Wahington']
data[data['Cast']== 'Denzel Wahington']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
data_new = data.dropna()

# %%
data_new.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico   2016-12-23
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore   2018-12-20
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
data_new[data_new['Cast'].str.contains('Denzel Washington')]
# Out:
#      Show_Id Category                     Title  \
# 1293   s1294    Movie             Chasing Trane
# 2097   s2098    Movie                    Fallen
# 2434   s2435    Movie              Giving Voice
# 2622   s2623    Movie              Hard Lessons
# 4845   s4845    Movie              Philadelphia
# 6156   s6156    Movie           The Book of Eli
# 6747   s6746    Movie         The Pelican Brief
# 6921   s6920    Movie  The Taking of Pelham 123
#
#                               Director  \
# 1293                   John Scheinfeld
# 2097                    Gregory Hoblit
# 2434  James D. Stern, Fernando Villena
# 2622                   Eric Laneuville
# 4845                    Jonathan Demme
# 6156       Albert Hughes, Allen Hughes
# 6747                    Alan J. Pakula
# 6921                        Tony Scott
#
#                                                    Cast  \
# 1293  Denzel Washington, Bill Clinton, Ravi Coltrane...
# ...

# %%
 # data.Rating.nunique()
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
 data.Rating.nunique()
# Out:
# 14

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
Q9. How many movies got the 'TV-14' rating, in United States?

# %%
data.head(20)
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 1       s2    Movie   07:19     Jorge Michel Grau
# 2       s3    Movie   23:59          Gilbert Chan
# 3       s4    Movie       9           Shane Acker
# 4       s5    Movie      21        Robert Luketic
# 5       s6  TV Show      46           Serdar Akar
# 6       s7    Movie     122       Yasir Al Yasiri
# 7       s8    Movie     187        Kevin Reynolds
# 8       s9    Movie     706         Shravan Kumar
# 9      s10    Movie    1920          Vikram Bhatt
# 10     s11    Movie    1922          Zak Hilditch
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 13     s14    Movie   2,215   Nottapon Boonprakob
# 14     s15    Movie    3022            John Suits
# 15     s16    Movie  Oct-01        Kunle Afolayan
# 16     s17  TV Show  Feb-09                   NaN
# 17     s18    Movie  22-Jul       Paul Greengrass
# ...

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-14')].shape
# Out:
# (1272, 13)

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-14') & (data['Country']=='United States')]
# Out:
#      Show_Id Category                                     Title  \
# 33       s34    Movie                              #realityhigh
# 47       s48    Movie                             1 Mile to You
# 56       s57    Movie  100 Years: One Woman's Fight for Justice
# 184     s185    Movie    A Haunting at Silver Falls: The Return
# 223     s224    Movie                             A Secret Love
# ...      ...      ...                                       ...
# 7563   s7562    Movie                        What Still Remains
# 7571   s7570    Movie               What Would Sophia Loren Do?
# 7588   s7587    Movie                         When We First Met
# 7644   s7643    Movie                                  Wish Man
# 7664   s7663    Movie                                   Work It
#
#               Director                                               Cast  \
# 33    Fernando Lebrija  Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-14') & (data['Country']=='United States')].shape
# Out:
# (200, 13)

# %%
Q9.2 How many TV Show got the 'R' rating, after year 2019?

# %%
data.head(20)
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 1       s2    Movie   07:19     Jorge Michel Grau
# 2       s3    Movie   23:59          Gilbert Chan
# 3       s4    Movie       9           Shane Acker
# 4       s5    Movie      21        Robert Luketic
# 5       s6  TV Show      46           Serdar Akar
# 6       s7    Movie     122       Yasir Al Yasiri
# 7       s8    Movie     187        Kevin Reynolds
# 8       s9    Movie     706         Shravan Kumar
# 9      s10    Movie    1920          Vikram Bhatt
# 10     s11    Movie    1922          Zak Hilditch
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 13     s14    Movie   2,215   Nottapon Boonprakob
# 14     s15    Movie    3022            John Suits
# 15     s16    Movie  Oct-01        Kunle Afolayan
# 16     s17  TV Show  Feb-09                   NaN
# 17     s18    Movie  22-Jul       Paul Greengrass
# ...

# %%
data[(data['Category'] == 'TV Show') & (data['Rating'] == 'R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway   2016-12-10
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration                                             Type  \
# 4497      R  1 Season  International TV Shows, TV Dramas, TV Thrillers
# 6437      R  1 Season                                         TV Shows
#
#                                             Description     Date_N    Year
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10  2016.0
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
data[(data['Category'] == 'TV Show') & (data['Rating'] == 'R') & (data['Year'] > 2016)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
Q.10 What is the maximum duration of a Movie/Show on Netflix?

# %%
data.head(20)
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 1       s2    Movie   07:19     Jorge Michel Grau
# 2       s3    Movie   23:59          Gilbert Chan
# 3       s4    Movie       9           Shane Acker
# 4       s5    Movie      21        Robert Luketic
# 5       s6  TV Show      46           Serdar Akar
# 6       s7    Movie     122       Yasir Al Yasiri
# 7       s8    Movie     187        Kevin Reynolds
# 8       s9    Movie     706         Shravan Kumar
# 9      s10    Movie    1920          Vikram Bhatt
# 10     s11    Movie    1922          Zak Hilditch
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 13     s14    Movie   2,215   Nottapon Boonprakob
# 14     s15    Movie    3022            John Suits
# 15     s16    Movie  Oct-01        Kunle Afolayan
# 16     s17  TV Show  Feb-09                   NaN
# 17     s18    Movie  22-Jul       Paul Greengrass
# ...

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %%
data.head(20)
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 1       s2    Movie   07:19     Jorge Michel Grau
# 2       s3    Movie   23:59          Gilbert Chan
# 3       s4    Movie       9           Shane Acker
# 4       s5    Movie      21        Robert Luketic
# 5       s6  TV Show      46           Serdar Akar
# 6       s7    Movie     122       Yasir Al Yasiri
# 7       s8    Movie     187        Kevin Reynolds
# 8       s9    Movie     706         Shravan Kumar
# 9      s10    Movie    1920          Vikram Bhatt
# 10     s11    Movie    1922          Zak Hilditch
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 13     s14    Movie   2,215   Nottapon Boonprakob
# 14     s15    Movie    3022            John Suits
# 15     s16    Movie  Oct-01        Kunle Afolayan
# 16     s17  TV Show  Feb-09                   NaN
# 17     s18    Movie  22-Jul       Paul Greengrass
# ...

# %%
data[['Minutes', 'Unit']] = data['Duration'].str.split(' ', n=1, expand=True)

# %%
data.head(20)
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 1       s2    Movie   07:19     Jorge Michel Grau
# 2       s3    Movie   23:59          Gilbert Chan
# 3       s4    Movie       9           Shane Acker
# 4       s5    Movie      21        Robert Luketic
# 5       s6  TV Show      46           Serdar Akar
# 6       s7    Movie     122       Yasir Al Yasiri
# 7       s8    Movie     187        Kevin Reynolds
# 8       s9    Movie     706         Shravan Kumar
# 9      s10    Movie    1920          Vikram Bhatt
# 10     s11    Movie    1922          Zak Hilditch
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 13     s14    Movie   2,215   Nottapon Boonprakob
# 14     s15    Movie    3022            John Suits
# 15     s16    Movie  Oct-01        Kunle Afolayan
# 16     s17  TV Show  Feb-09                   NaN
# 17     s18    Movie  22-Jul       Paul Greengrass
# ...

# %%
data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].min()
# Out:
# '1'

# %%
data['Minutes'].mean()
# Out:
# np.float64(69.12276871709258)

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# Year                   float64
# Minutes                  int64
# Unit                    object
# dtype: object

# %%
Q.11 Which individual country has the Highest No. of TV Shows?

# %%
data_tvshow = data[data['Category'] == 'TV Show']

# %%
data_tvshow.head(20)
# Out:
#    Show_Id Category                                Title  \
# 0       s1  TV Show                                   3%
# 5       s6  TV Show                                   46
# 11     s12  TV Show                                 1983
# 12     s13  TV Show                                 1994
# 16     s17  TV Show                               Feb-09
# 24     s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac
# 26     s27  TV Show                             (Un)Well
# 29     s30  TV Show                             #blackAF
# 38     s39  TV Show                  แผนร้ายนายเจ้าเล่ห์
# 45     s46  TV Show                                Şubat
# 51     s52  TV Show                   100 Days My Prince
# 53     s54  TV Show                           100 Humans
# 58     s59  TV Show                          100% Hotter
# 61     s62  TV Show                     12 Years Promise
# 63     s64  TV Show                       13 Reasons Why
# ...

# %%
data_tvshow.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
data_tvshow.Country.value_counts().head()
# Out:
# Country
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Name: count, dtype: int64

# %%
Q.12 How can we sort the dataset by Year?

# %%
data.head(20)
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 1       s2    Movie   07:19     Jorge Michel Grau
# 2       s3    Movie   23:59          Gilbert Chan
# 3       s4    Movie       9           Shane Acker
# 4       s5    Movie      21        Robert Luketic
# 5       s6  TV Show      46           Serdar Akar
# 6       s7    Movie     122       Yasir Al Yasiri
# 7       s8    Movie     187        Kevin Reynolds
# 8       s9    Movie     706         Shravan Kumar
# 9      s10    Movie    1920          Vikram Bhatt
# 10     s11    Movie    1922          Zak Hilditch
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 13     s14    Movie   2,215   Nottapon Boonprakob
# 14     s15    Movie    3022            John Suits
# 15     s16    Movie  Oct-01        Kunle Afolayan
# 16     s17  TV Show  Feb-09                   NaN
# 17     s18    Movie  22-Jul       Paul Greengrass
# ...

# %%
data.sort_values(by = 'Year')
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show              Dinner for Five                   NaN
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                          ...                   ...
# 6952   s6951  TV Show                   The Tudors                   NaN
# 6998   s6997  TV Show                The West Wing                   NaN
# 7448   s7447  TV Show                      Vroomiz                   NaN
# 7524   s7523  TV Show   Weird Wonders of the World                   NaN
# 7655   s7654  TV Show            Women Behind Bars                   NaN
#
#                                                    Cast  \
# ...

# %%
data.sort_values(by = 'Year', ascending = False).head(10)
# Out:
#      Show_Id Category                                              Title  \
# 5564   s5564    Movie                                    Sherlock Holmes
# 5919   s5919    Movie                                          Surf's Up
# 980     s981  TV Show                                       Bling Empire
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 5955   s5955    Movie                                   Taare Zameen Par
# 366     s367    Movie                                          Al acecho
# 560     s561    Movie                                           Apaharan
# 5922   s5922  TV Show                                    Surviving Death
# 4269   s4270    Movie                                                Mud
# 1002   s1003    Movie                                        Blue Streak
#
#                      Director  \
# 5564              Guy Ritchie
# 5919  Ash Brannon, Chris Buck
# 980                       NaN
# 1355               Chris Rock
# ...

# %%
Q.13 Finding all the instances where: Category is 'Movie' & Type of 'Dramas' or Category is 'TV Show' & Type of 'Kids'TV'

# %%
data.head(20)
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 1       s2    Movie   07:19     Jorge Michel Grau
# 2       s3    Movie   23:59          Gilbert Chan
# 3       s4    Movie       9           Shane Acker
# 4       s5    Movie      21        Robert Luketic
# 5       s6  TV Show      46           Serdar Akar
# 6       s7    Movie     122       Yasir Al Yasiri
# 7       s8    Movie     187        Kevin Reynolds
# 8       s9    Movie     706         Shravan Kumar
# 9      s10    Movie    1920          Vikram Bhatt
# 10     s11    Movie    1922          Zak Hilditch
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 13     s14    Movie   2,215   Nottapon Boonprakob
# 14     s15    Movie    3022            John Suits
# 15     s16    Movie  Oct-01        Kunle Afolayan
# 16     s17  TV Show  Feb-09                   NaN
# 17     s18    Movie  22-Jul       Paul Greengrass
# ...

# %%
data[(data['Category']== 'Movie') & (data['Type']== 'Dramas')].head(5)
# Out:
#     Show_Id Category                       Title        Director  \
# 4        s5    Movie                          21  Robert Luketic
# 7        s8    Movie                         187  Kevin Reynolds
# 170    s171    Movie                A Family Man   Mark Williams
# 232    s233    Movie  A Stoning in Fulham County   Larry Elikann
# 295    s296    Movie          Across Grace Alley   Ralph Macchio
#
#                                                   Cast                Country  \
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          United States
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...          United States
# 170  Gerard Butler, Gretchen Mol, Alison Brie, Will...  Canada, United States
# 232  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...          United States
# 295  Ben Hyland, Marsha Mason, Karina Smirnoff, Col...          United States
#
#     Release_Date Rating Duration    Type  \
# 4     2020-01-01  PG-13  123 min  Dramas
# ...

# %%
data[(data['Category'] == 'TV Show') & (data['Type'] == "Kids' TV")].head(5)
# Out:
#     Show_Id Category              Title             Director  \
# 111    s112  TV Show            44 Cats                  NaN
# 276    s277  TV Show       Abby Hatcher          Kyran Kelly
# 434    s435  TV Show        Alphablocks                  NaN
# 598    s599  TV Show  Ask the StoryBots                  NaN
# 706    s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
# 434    Teresa Gallagher, David Holt, Lizzie Waterworth         United Kingdom
# 598  Judy Greer, Erin Fitzgerald, Fred Tatasciore, ...          United States
# 706             Meghna Erande Joshi, Parminder Ghumman                    NaN
#
#     Release_Date Rating   Duration      Type  \
# 111   2020-10-01  TV-Y7  2 Seasons  Kids' TV
# ...

# %%
result = pd.concat([
    data[(data['Category'] == 'TV Show') & (data['Type'] == "Kids' TV")].head(5),
    data[(data['Category'] == 'Movie') & (data['Type'] == 'Dramas')].head(5)
])

result
# Out:
#     Show_Id Category                       Title             Director  \
# 111    s112  TV Show                     44 Cats                  NaN
# 276    s277  TV Show                Abby Hatcher          Kyran Kelly
# 434    s435  TV Show                 Alphablocks                  NaN
# 598    s599  TV Show           Ask the StoryBots                  NaN
# 706    s707  TV Show                  Bal Ganesh  Vijay S. Bhanushali
# 4        s5    Movie                          21       Robert Luketic
# 7        s8    Movie                         187       Kevin Reynolds
# 170    s171    Movie                A Family Man        Mark Williams
# 232    s233    Movie  A Stoning in Fulham County        Larry Elikann
# 295    s296    Movie          Across Grace Alley        Ralph Macchio
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# ...
